# %%
# Split
# where
# clip
# Broadcasting


# Pandas Introduction

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = plt.imread(r'C:\Users\mohiv\OneDrive\Pictures\OIP.jpg')
arr
# Out:
# array([[[ 45,  44,  39],
#         [ 44,  43,  38],
#         [ 43,  42,  37],
#         ...,
#         [ 59,  54,  34],
#         [ 59,  54,  34],
#         [ 60,  55,  35]],
#
#        [[ 45,  44,  39],
#         [ 44,  43,  38],
#         [ 43,  42,  37],
#         ...,
#         [ 59,  54,  34],
#         [ 59,  54,  34],
#         [ 60,  55,  35]],
#
#        [[ 45,  44,  39],
#         [ 44,  43,  38],
#         [ 43,  42,  37],
#         ...,
#         [ 59,  54,  34],
#         [ 59,  54,  34],
#         [ 60,  55,  35]],
#
#        ...,
#
#        [[148, 113,  94],
#         [166, 137, 119],
#         [222, 203, 186],
#         ...,
#         [ 60,  60,  52],
#         [ 62,  62,  54],
#         [ 68,  68,  60]],
#
#        [[122,  87,  68],
#         [135, 106,  88],
#         [219, 200, 183],
#         ...,
#         [ 62,  62,  54],
#         [ 65,  65,  57],
#         [ 71,  71,  63]],
#
#        [[ 90,  55,  36],
#         [135, 106,  88],
#         [221, 202, 185],
#         ...,
#         [ 64,  64,  56],
#         [ 67,  67,  59],
#         [ 74,  74,  66]]], dtype=uint8)

# %%
OIP_arr = arr.copy()

# %%
plt.imshow(OIP_arr)

# %%
OIP_arr.shape
# Out:
# (180, 320, 3)

# %%
a = np.random.randint(0,255,(50,50,3))
plt.imshow(a)

# %%
while True:
  import numpy as np
  import matplotlib.pyplot as plt
  import time
  a = np.random.randint(0,255,(5,5,3))
  plt.imshow(a)
  plt.show()
  time.sleep(0.3)
  display(clear = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 8
#       6 plt.imshow(a)
#       7 plt.show()
# ----> 8 time.sleep(0.3)
#       9 display(clear = True)
#
# KeyboardInterrupt:

# %%
a = np.random.randint(0,255,(4,4,3))
a
# Out:
# array([[[158,  55, 147],
#         [ 12, 116, 248],
#         [ 62, 252,  16],
#         [250, 237, 170]],
#
#        [[ 52,  63, 220],
#         [ 76, 221, 196],
#         [214, 159, 142],
#         [ 81, 253,  50]],
#
#        [[210, 111,  71],
#         [168, 207,  24],
#         [ 22,  57, 118],
#         [ 67, 101,  44]],
#
#        [[ 92,  45,  89],
#         [ 74,  43,   9],
#         [ 42,  74,  77],
#         [119, 250,  91]]])

# %%
final_arr = np.split(a,2)
len(final_arr)
# Out:
# 2

# %%
plt.imshow(a)

# %%
plt.imshow(final_arr[0])

# %%
plt.imshow(a)

# %%
arr_1 = np.split(a,2,axis = 1)

# %%
len(arr_1)
# Out:
# 2

# %%
a
# Out:
# array([[[158,  55, 147],
#         [ 12, 116, 248],
#         [ 62, 252,  16],
#         [250, 237, 170]],
#
#        [[ 52,  63, 220],
#         [ 76, 221, 196],
#         [214, 159, 142],
#         [ 81, 253,  50]],
#
#        [[210, 111,  71],
#         [168, 207,  24],
#         [ 22,  57, 118],
#         [ 67, 101,  44]],
#
#        [[ 92,  45,  89],
#         [ 74,  43,   9],
#         [ 42,  74,  77],
#         [119, 250,  91]]])

# %%
arr_1
# Out:
# [array([[[158,  55, 147],
#          [ 12, 116, 248]],
#
#         [[ 52,  63, 220],
#          [ 76, 221, 196]],
#
#         [[210, 111,  71],
#          [168, 207,  24]],
#
#         [[ 92,  45,  89],
#          [ 74,  43,   9]]]),
#  array([[[ 62, 252,  16],
#          [250, 237, 170]],
#
#         [[214, 159, 142],
#          [ 81, 253,  50]],
#
#         [[ 22,  57, 118],
#          [ 67, 101,  44]],
#
#         [[ 42,  74,  77],
#          [119, 250,  91]]])]

# %%
a.shape
# Out:
# (4, 4, 3)

# %%
np.split(a,3, axis = 2)
# Out:
# [array([[[158],
#          [ 12],
#          [ 62],
#          [250]],
#
#         [[ 52],
#          [ 76],
#          [214],
#          [ 81]],
#
#         [[210],
#          [168],
#          [ 22],
#          [ 67]],
#
#         [[ 92],
#          [ 74],
#          [ 42],
#          [119]]]),
#  array([[[ 55],
#          [116],
#          [252],
#          [237]],
#
#         [[ 63],
#          [221],
#          [159],
#          [253]],
#
#         [[111],
#          [207],
#          [ 57],
#          [101]],
#
#         [[ 45],
#          [ 43],
#          [ 74],
#          [250]]]),
#  array([[[147],
#          [248],
#          [ 16],
#          [170]],
#
#         [[220],
#          [196],
#          [142],
#          [ 50]],
#
#         [[ 71],
#          [ 24],
#          [118],
#          [ 44]],
#
#         [[ 89],
#          [  9],
#          [ 77],
#          [ 91]]])]

# %%
a
# Out:
# array([[[158,  55, 147],
#         [ 12, 116, 248],
#         [ 62, 252,  16],
#         [250, 237, 170]],
#
#        [[ 52,  63, 220],
#         [ 76, 221, 196],
#         [214, 159, 142],
#         [ 81, 253,  50]],
#
#        [[210, 111,  71],
#         [168, 207,  24],
#         [ 22,  57, 118],
#         [ 67, 101,  44]],
#
#        [[ 92,  45,  89],
#         [ 74,  43,   9],
#         [ 42,  74,  77],
#         [119, 250,  91]]])

# %%
arr_3_part = np.split(a,3,axis = 2)

# %%
plt.imshow(a)

# %%
len(arr_3_part)
# Out:
# 3

# %%
plt.imshow(arr_3_part[0])

# %%
plt.imshow(arr_3_part[1])

# %%
plt.imshow(arr_3_part[2])

# %%
arr.shape
# Out:
# (180, 320, 3)

# %%
plt.imshow(np.split(arr,3,axis = 2)[2])

# %%
plt.imshow(np.split(arr,2,axis = 0)[0])

# %%
arr.shape
# Out:
# (180, 320, 3)

# %%
320//3
# Out:
# 106

# %%
plt.imshow(arr[:,:106,:])

# %%
plt.imshow(arr[:,106:106*2,:])

# %%
plt.imshow(arr[:,106*2:,:])

# %%
# where
# clip
# Broadcasting

# %%
a = np.random.randint(1,500,(4,4))
a
# Out:
# array([[299, 244, 226, 347],
#        [132, 125, 442, 142],
#        [424, 451, 203, 415],
#        [463, 440, 143,  55]])

# %%
np.where(a>200)
# Out:
# (array([0, 0, 0, 0, 1, 2, 2, 2, 2, 3, 3], dtype=int64),
#  array([0, 1, 2, 3, 2, 0, 1, 2, 3, 0, 1], dtype=int64))

# %%
np.where(a>200,'High Sales','Low Sales')
# Out:
# array([['High Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['Low Sales', 'Low Sales', 'High Sales', 'Low Sales'],
#        ['High Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['High Sales', 'High Sales', 'Low Sales', 'Low Sales']],
#       dtype='<U10')

# %%
np.where(a>200,'High Sales',a)
# Out:
# array([['High Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['132', '125', 'High Sales', '142'],
#        ['High Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['High Sales', 'High Sales', '143', '55']], dtype='<U11')

# %%
np.clip(a,100,250)#outliers remove/replace
# Out:
# array([[250, 244, 226, 250],
#        [132, 125, 250, 142],
#        [250, 250, 203, 250],
#        [250, 250, 143, 100]])

# %%
#broadcasting

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(2,2))

print(a)
print('-------\n\n')
print(b)
# Out:
# [6 1 3 4 5 9 2]
# -------
#
#
# [[7 1]
#  [2 3]]

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(2,7))

print(a)
print('-------\n\n')
print(b)
# Out:
# [8 6 6 2 9 2 6]
# -------
#
#
# [[6 7 5 3 2 5 7]
#  [3 7 4 2 7 6 5]]

# %%
a+b
# Out:
# array([[14, 13, 11,  5, 11,  7, 13],
#        [11, 13, 10,  4, 16,  8, 11]])

# %%
a*b
# Out:
# array([[48, 42, 30,  6, 18, 10, 42],
#        [24, 42, 24,  4, 63, 12, 30]])

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(7,7))

print(a)
print('-------\n\n')
print(b)
# Out:
# [5 5 7 1 6 7 4]
# -------
#
#
# [[7 5 3 2 1 6 8]
#  [3 8 8 5 3 5 2]
#  [2 9 6 2 6 2 5]
#  [8 8 3 3 1 5 8]
#  [8 6 2 9 3 9 3]
#  [6 9 6 8 8 3 4]
#  [8 6 6 6 8 4 4]]

# %%
a+b
# Out:
# array([[12, 10, 10,  3,  7, 13, 12],
#        [ 8, 13, 15,  6,  9, 12,  6],
#        [ 7, 14, 13,  3, 12,  9,  9],
#        [13, 13, 10,  4,  7, 12, 12],
#        [13, 11,  9, 10,  9, 16,  7],
#        [11, 14, 13,  9, 14, 10,  8],
#        [13, 11, 13,  7, 14, 11,  8]])

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(1,7))

print(a)
print('-------\n\n')
print(b)
# Out:
# [7 2 8 7 3 4 5]
# -------
#
#
# [[9 3 7 6 1 8 3]]

# %%
a+b
# Out:
# array([[16,  5, 15, 13,  4, 12,  8]])

# %%
a = np.random.randint(1,10,(7,1))
b = np.random.randint(1,10,(1,7))

print(a)
print('-------\n\n')
print(b)
# Out:
# [[3]
#  [6]
#  [5]
#  [8]
#  [9]
#  [4]
#  [3]]
# -------
#
#
# [[9 1 6 6 4 8 2]]

# %%
a+b
# Out:
# array([[12,  4,  9,  9,  7, 11,  5],
#        [15,  7, 12, 12, 10, 14,  8],
#        [14,  6, 11, 11,  9, 13,  7],
#        [17,  9, 14, 14, 12, 16, 10],
#        [18, 10, 15, 15, 13, 17, 11],
#        [13,  5, 10, 10,  8, 12,  6],
#        [12,  4,  9,  9,  7, 11,  5]])

# %%
a = np.random.randint(1,10,(2,7))
b = np.random.randint(1,10,(1,7))

print(a)
print('-------\n\n')
print(b)
# Out:
# [[9 4 8 7 9 6 9]
#  [1 5 6 9 6 1 3]]
# -------
#
#
# [[3 3 5 3 8 1 5]]

# %%
a+b
# Out:
# array([[12,  7, 13, 10, 17,  7, 14],
#        [ 4,  8, 11, 12, 14,  2,  8]])

# %%
a = np.random.randint(1,10,(1,1))
b = np.random.randint(1,10,(5,7))

print(a)
print('-------\n\n')
print(b)
# Out:
# [[2]]
# -------
#
#
# [[5 4 3 9 9 1 4]
#  [6 5 8 4 8 9 3]
#  [5 9 1 2 9 4 8]
#  [5 4 1 4 4 1 8]
#  [9 3 2 7 9 7 7]]

# %%
a+b
# Out:
# array([[ 7,  6,  5, 11, 11,  3,  6],
#        [ 8,  7, 10,  6, 10, 11,  5],
#        [ 7, 11,  3,  4, 11,  6, 10],
#        [ 7,  6,  3,  6,  6,  3, 10],
#        [11,  5,  4,  9, 11,  9,  9]])

# %%
a = np.random.randint(1,10,(1,1,5))
b = np.random.randint(1,10,(5,5,5))

print(a)
print('-------\n\n')
print(b)
# Out:
# [[[7 5 9 6 1]]]
# -------
#
#
# [[[2 2 5 4 2]
#   [4 9 7 8 7]
#   [5 7 8 6 4]
#   [6 2 9 2 8]
#   [3 7 5 8 2]]
#
#  [[7 1 2 8 5]
#   [3 2 7 7 7]
#   [1 7 2 2 3]
#   [7 8 7 8 9]
#   [5 8 5 6 7]]
#
#  [[7 5 6 2 7]
#   [7 9 9 7 9]
#   [8 2 6 7 1]
#   [3 2 2 8 5]
#   [6 7 7 2 9]]
#
#  [[4 4 7 4 4]
#   [7 2 1 6 4]
#   [3 4 6 4 2]
#   [4 4 8 8 6]
#   [3 5 9 3 5]]
#
#  [[8 1 8 4 2]
#   [8 1 3 5 8]
#   [1 9 4 8 7]
#   [4 4 3 5 5]
#   [6 4 9 6 2]]]

# %%
a+b
# Out:
# array([[[ 9,  7, 14, 10,  3],
#         [11, 14, 16, 14,  8],
#         [12, 12, 17, 12,  5],
#         [13,  7, 18,  8,  9],
#         [10, 12, 14, 14,  3]],
#
#        [[14,  6, 11, 14,  6],
#         [10,  7, 16, 13,  8],
#         [ 8, 12, 11,  8,  4],
#         [14, 13, 16, 14, 10],
#         [12, 13, 14, 12,  8]],
#
#        [[14, 10, 15,  8,  8],
#         [14, 14, 18, 13, 10],
#         [15,  7, 15, 13,  2],
#         [10,  7, 11, 14,  6],
#         [13, 12, 16,  8, 10]],
#
#        [[11,  9, 16, 10,  5],
#         [14,  7, 10, 12,  5],
#         [10,  9, 15, 10,  3],
#         [11,  9, 17, 14,  7],
#         [10, 10, 18,  9,  6]],
#
#        [[15,  6, 17, 10,  3],
#         [15,  6, 12, 11,  9],
#         [ 8, 14, 13, 14,  8],
#         [11,  9, 12, 11,  6],
#         [13,  9, 18, 12,  3]]])

# %%
#Introduction to pandas

# %%
# data Science
# data : Explore (Exploratory Data Analysis)
# EDA

# %%
# # Anupam: lives in nainital
# # Piyush = 100
# # Explore
# Excel: EDA
# SQL :- EDA
# PowerBI: EDA
# Python: EDA

# %%
# Python:- Programming language
# pandas: File Handling()
# pandas:- table

# %%
# dataframe: df

# %%
# Data Explore:- Report(Insights)

# Report>>> Data Scientist

# %%
import numpy as np
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
import random

products = ['Chair','Tables','Laptop','Mobile Phones','Charger']
region = ['East','West','North','South']
all_date = pd.date_range('01-01-2025','23-07-2025')

data = {'Order_id':range(1,1001),
        'Date':random.choices(all_date,k =1000),
        'Region Name':random.choices(region,k = 1000),
        'Product Name':random.choices(products,k = 1000),
        'Sales':np.random.randint(100,10000,1000),
        'Qty':np.random.randint(1,10,1000),
        'Profit':np.random.randint(-10000,10000,1000)}

table = pd.DataFrame(data)
table
# Out:
#      Order_id       Date Region Name   Product Name  Sales  Qty  Profit
# 0           1 2025-05-28       South        Charger    711    1     549
# 1           2 2025-06-06       North        Charger   7493    4    3744
# 2           3 2025-03-22        East          Chair   6968    4     773
# 3           4 2025-03-20       South        Charger   7165    3   -4723
# 4           5 2025-05-25        East  Mobile Phones   4819    9   -7816
# ..        ...        ...         ...            ...    ...  ...     ...
# 995       996 2025-03-14        East         Tables   7226    9     -98
# 996       997 2025-05-02        West        Charger   5242    3    5364
# 997       998 2025-05-16       North  Mobile Phones   4930    6    6299
# 998       999 2025-02-05       North         Tables   7740    5    4954
# 999      1000 2025-02-11        West         Laptop   9252    3    3383
#
# [1000 rows x 7 columns]

# %%
#date column

# %%
pd.date_range('01-01-2025','23-07-2025')
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10',
#                ...
#                '2025-07-14', '2025-07-15', '2025-07-16', '2025-07-17',
#                '2025-07-18', '2025-07-19', '2025-07-20', '2025-07-21',
#                '2025-07-22', '2025-07-23'],
#               dtype='datetime64[ns]', length=204, freq='D')

# %%
table
# Out:
#      Order_id       Date Region Name   Product Name  Sales  Qty  Profit
# 0           1 2025-05-28       South        Charger    711    1     549
# 1           2 2025-06-06       North        Charger   7493    4    3744
# 2           3 2025-03-22        East          Chair   6968    4     773
# 3           4 2025-03-20       South        Charger   7165    3   -4723
# 4           5 2025-05-25        East  Mobile Phones   4819    9   -7816
# ..        ...        ...         ...            ...    ...  ...     ...
# 995       996 2025-03-14        East         Tables   7226    9     -98
# 996       997 2025-05-02        West        Charger   5242    3    5364
# 997       998 2025-05-16       North  Mobile Phones   4930    6    6299
# 998       999 2025-02-05       North         Tables   7740    5    4954
# 999      1000 2025-02-11        West         Laptop   9252    3    3383
#
# [1000 rows x 7 columns]

# %%
table.head()
# Out:
#    Order_id       Date Region Name   Product Name  Sales  Qty  Profit
# 0         1 2025-05-28       South        Charger    711    1     549
# 1         2 2025-06-06       North        Charger   7493    4    3744
# 2         3 2025-03-22        East          Chair   6968    4     773
# 3         4 2025-03-20       South        Charger   7165    3   -4723
# 4         5 2025-05-25        East  Mobile Phones   4819    9   -7816

# %%
table.tail()
# Out:
#      Order_id       Date Region Name   Product Name  Sales  Qty  Profit
# 995       996 2025-03-14        East         Tables   7226    9     -98
# 996       997 2025-05-02        West        Charger   5242    3    5364
# 997       998 2025-05-16       North  Mobile Phones   4930    6    6299
# 998       999 2025-02-05       North         Tables   7740    5    4954
# 999      1000 2025-02-11        West         Laptop   9252    3    3383

# %%
table.sample()
# Out:
#      Order_id       Date Region Name Product Name  Sales  Qty  Profit
# 735       736 2025-04-07       South      Charger   8752    4    3128

# %%
table.sample(5)
# Out:
#      Order_id       Date Region Name   Product Name  Sales  Qty  Profit
# 160       161 2025-07-22        West  Mobile Phones   4538    9   -1678
# 359       360 2025-07-14        East         Laptop   7173    1   -5978
# 661       662 2025-06-05        East         Tables    927    4    5704
# 547       548 2025-03-11       North        Charger    423    6    -274
# 633       634 2025-02-13       South          Chair   1533    6    8919

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_id      1000 non-null   int64
#  1   Date          1000 non-null   datetime64[ns]
#  2   Region Name   1000 non-null   object
#  3   Product Name  1000 non-null   object
#  4   Sales         1000 non-null   int32
#  5   Qty           1000 non-null   int32
#  6   Profit        1000 non-null   int32
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 43.1+ KB

# %%
table.columns
# Out:
# Index(['Order_id', 'Date', 'Region Name', 'Product Name', 'Sales', 'Qty',
#        'Profit'],
#       dtype='object')

# %%
table.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# isna(): it will check nan value counts

table.isna()
# Out:
#      Order_id   Date  Region Name  Product Name  Sales    Qty  Profit
# 0       False  False        False         False  False  False   False
# 1       False  False        False         False  False  False   False
# 2       False  False        False         False  False  False   False
# 3       False  False        False         False  False  False   False
# 4       False  False        False         False  False  False   False
# ..        ...    ...          ...           ...    ...    ...     ...
# 995     False  False        False         False  False  False   False
# 996     False  False        False         False  False  False   False
# 997     False  False        False         False  False  False   False
# 998     False  False        False         False  False  False   False
# 999     False  False        False         False  False  False   False
#
# [1000 rows x 7 columns]

# %%
table.isna().value_counts()
# Out:
# Order_id  Date   Region Name  Product Name  Sales  Qty    Profit
# False     False  False        False         False  False  False     1000
# Name: count, dtype: int64
